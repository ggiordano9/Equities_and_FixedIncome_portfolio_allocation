# %%
'''
Github link for a module made (yesg - p) to retreive ESG Scores from yahoo finance, including historical ones:
https://github.com/Lienus10/yesg/blob/master/yesg/main.py

'''

import yesg
import pandas as pd
import calendar
import urllib.request
import json
import requests

sp_500 = pd.read_csv('sandp500.csv') 

# Downloads historic ESG ratings and returns it as a dataframe

def get_historic_esg(ticker):
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) '
                             'Chrome/50.0.2661.102 Safari/537.36'}

    response = requests.get('https://query2.finance.yahoo.com/v1/finance/esgChart', params={"symbol": ticker},
                            headers=headers)

    try:
        df = pd.DataFrame(response.json()["esgChart"]["result"][0]["symbolSeries"])
        df["Date"] = pd.to_datetime(df["timestamp"], unit="s")

        df = df.rename(columns={"esgScore": "Total-Score", "environmentScore": "E-Score", "socialScore": "S-Score",
                                "governanceScore": "G-Score"})
        df["Ticker"] = ticker

        return df[['Date', 'Total-Score', 'E-Score', 'S-Score', 'G-Score', 'Ticker']].set_index('Date')

    except:
        print('An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.')


'''
Or, using yesg module, could just do:
df = yesg.get_historic_esg('JPM')
df

'''
# Out:
# "\nOr, using yesg module, could just do:\ndf = yesg.get_historic_esg('JPM')\ndf\n\n"

# %%
get_historic_esg('AAPL')
# Out:
#             Total-Score  E-Score  S-Score  G-Score Ticker
# Date
# 2014-09-01        61.00    74.00    45.00    62.00   AAPL
# 2014-10-01        60.00    74.00    45.00    62.00   AAPL
# 2014-11-01        61.00    74.00    45.00    62.00   AAPL
# 2014-12-01        61.00    74.00    45.00    62.00   AAPL
# 2015-01-01        61.00    74.00    45.00    62.00   AAPL
# ...                 ...      ...      ...      ...    ...
# 2021-05-01        16.92     0.29     7.69     8.94   AAPL
# 2021-06-01          NaN      NaN      NaN      NaN   AAPL
# 2021-07-01          NaN      NaN      NaN      NaN   AAPL
# 2021-08-01          NaN      NaN      NaN      NaN   AAPL
# 2021-09-01        16.92     0.29     7.99     8.64   AAPL
#
# [85 rows x 5 columns]

# %%
appended_data = []
for Ticker in sp_500['Ticker']:
    a_data = get_historic_esg(Ticker)
    appended_data.append(a_data)
appended_data = pd.concat(appended_data)
appended_data
# Out:
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# An error has occurred. The ticker symbol might be wrong or you might need to wait to continue.
# ...

# %%
tickers_that_worked = appended_data['Ticker'].tolist()

# %%
distinct_tickers_that_worked = set(tickers_that_worked)

# %%
distinct_tickers_that_worked
# Out:
# {'AAPL',
#  'ABBV',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AMAT',
#  'AMGN',
#  'AMT',
#  'AMZN',
#  'ANTM',
#  'ATVI',
#  'AVGO',
#  'AXP',
#  'BA',
#  'BAC',
#  'BDX',
#  'BKNG',
#  'BLK',
#  'BMY',
#  'C',
#  'CAT',
#  'CB',
#  'CE',
#  'CHTR',
#  'CI',
#  'CL',
#  'CMCSA',
#  'CME',
#  'COST',
#  'CRM',
#  'CSCO',
#  'CSX',
#  'CVS',
#  'CVX',
#  'DE',
#  'DHR',
#  'DIS',
#  'ES',
#  'FB',
#  'FIS',
#  'GE',
#  'GILD',
#  'GOOGL',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'INTU',
#  'ISRG',
#  'JNJ',
#  'JPM',
#  'KO',
#  'LLY',
#  'LMT',
#  'LOW',
#  'LRCX',
#  'MA',
#  'MCD',
#  'MDLZ',
#  'MDT',
#  'MMM',
#  'MO',
#  'MRK',
#  'MS',
#  'MSFT',
#  'MU',
#  'NEE',
#  'NFLX',
#  'NKE',
#  'NOW',
#  'NVDA',
#  'OMC',
#  'ORCL',
#  'OXY',
#  'PCAR',
#  'PEP',
#  'PFE',
#  'PG',
#  'PLD',
#  'PM',
#  'PSX',
#  'PYPL',
#  'QCOM',
#  'RTX',
#  'SBUX',
#  'SCHW',
#  'SPGI',
#  'SYK',
#  'T',
#  'TFC',
#  'TGT',
#  'TJX',
#  'TMO',
#  'TMUS',
# ...

# %%
length_of_tickers_worked = len(distinct_tickers_that_worked)
length_of_tickers_worked
# Out:
# 110

# %%
# 110 out of 500 (s&p500) tickers we are able to get the ESG Scores for
